# %%
import numpy as np
import matplotlib.pyplot as plt

# For deep learning
import tensorflow as tf
import keras as keras
import keras.layers as layers
import keras.initializers as initializers

import random

# For solving eq
from scipy import integrate

# For environment
import gym
from gym import spaces

# %%
tf.random.set_seed(2304)
np.random.seed(2304)

# %%
N_ACTIONS = 5
N_STATE = 2
max_steps = 200

# %% [markdown]
# # Solver

# %%
def derivative(X, t, alpha, beta, delta, gamma):
    x, y = X
    dotx = x * (alpha - beta * y)
    doty = y * (-delta + gamma * x)
    return np.array([dotx, doty])

# %%
class Plotter:

  def __init__(self, Nt, tmax) -> None:
    
    self.Nt = Nt
    self.tmax = tmax
    self.alphas, self.deltas = [], []
    self.t_vec  = []
    self.X_vec, self.Y_vec = [], []

  def add_data(self, new_t, res, new_alpha, new_delta) -> None:

    offset = self.tmax / (self.Nt - 1) + self.t_vec[-1] if len(self.t_vec) > 0 else self.tmax / (self.Nt - 1)
    new_t = new_t + offset
    self.t_vec = np.concatenate([self.t_vec, new_t])
    new_x, new_y = res.T
    new_alpha_vec = np.ones(shape=new_x.shape) * new_alpha
    new_delta_vec = np.ones(shape=new_x.shape) * new_delta
    self.X_vec = np.concatenate([self.X_vec, new_x])
    self.Y_vec = np.concatenate([self.Y_vec, new_y])
    self.alphas = np.concatenate([self.alphas, new_alpha_vec])
    self.deltas = np.concatenate([self.deltas, new_delta_vec])
    
    return

  def plot(self):
    # plot it
    f, (a0, a1, a2) = plt.subplots(3, 1, gridspec_kw={'height_ratios': [2, 1.5, 1.5]}, figsize=(8,7))

    a0.plot(self.t_vec, self.X_vec)
    a0.plot(self.t_vec, self.Y_vec)
    a0.set(ylim=(0, 10 + max(np.max(self.X_vec), np.max(self.Y_vec))))
    a0.hlines(y=4, xmin=self.t_vec[0], xmax=self.t_vec[-1], linestyles='dashed')
    a0.set_xlabel('Time t, [days]')
    a0.set_ylabel('Population')
    a0.legend(['Prey', 'Predator', 'Extinction'])

    a1.plot(self.t_vec, self.alphas, color='red')
    a1.set_yticks([0.5, 0.75, 1, 1.25, 1.5])
    a1.set(ylim=(0, 2))
    a1.set_xlabel('Time t, [days]')
    a1.legend(['alpha'])

    a2.plot(self.t_vec, self.deltas, color='blue')
    a2.set_yticks([0.75, 1, 1.25, 1.5, 1.75])
    a2.set(ylim=(0, 2))
    a2.set_xlabel('Time t, [days]')
    a2.legend(['delta'])


    f.tight_layout()

    return

# %%
class CustomEnv(gym.Env):
  """Custom Environment that follows gym interface"""

  metadata = {'render.modes': ['human']}

  def __init__(self, X0, params, N_ACTIONS):
    super(CustomEnv, self).__init__()

    # Example when using discrete actions:
    self.action_space = spaces.Discrete(N_ACTIONS)
    self.action_vec  = [[a,b] for a in np.linspace(0.5, 1.5, N_ACTIONS) for b in np.linspace(0.5, 1.5, N_ACTIONS) ]
    self.observation_space = spaces.Box(low=np.array([0,0]), 
                                        high=np.array([1000,1000]), dtype=np.float64)

    #Params related to differential equation
    self.X0, self.Xt, self.alpha0, self.delta0 = np.array(X0), np.array(X0), params['alpha'], params['delta']
    self.params = params
    self.Nt, self.tmax = 100, 2.
    self.plotter = Plotter(Nt=self.Nt, tmax=self.tmax)


  def reset(self):
    self.params['alpha'] = self.alpha0
    self.params['delta'] = self.delta0
    self.Xt = self.X0
    self.plotter = Plotter(Nt=100, tmax=2)

  def get_action_value(self, action):
    return self.action_vec[action]

  def get_reward(self, res, step_counter, extinction_threshold = [4, 5]):

    done = False

    if np.min(res) < extinction_threshold[0]:
      reward = -1000
      done = True
      # print('----- Extinction -----')

    #elif np.min(res) < extinction_threshold[1]:
    #  reward = -10

    elif step_counter == max_steps:
      reward = 500
    
    else:
      reward = -1

    return reward, done

  def step(self, action, step_counter, inplace=False, plot=False, train=False):

    # Assert that it is a valid action 
    #assert self.action_space.contains([action[0], action[1]]), "Invalid Action"

    # Apply action
    self.params['alpha'] = self.get_action_value(action)[0]
    self.params['delta'] = self.get_action_value(action)[1]

    # Evolution of differential equation
    t = np.linspace(0., self.tmax, self.Nt)
    res = integrate.odeint(derivative, self.Xt, t, args = (self.params['alpha'], 
                                                           self.params['beta'], 
                                                           self.params['delta'], 
                                                           self.params['gamma']))

    # Eventual plot of the equation
    if inplace:
      self.Xt = np.array(res[-1])
      self.plotter.add_data(new_t=t, res=res, new_alpha=self.params['alpha'], 
                            new_delta=self.params['delta'])

    if not train:
      print("alpha: ", self.params['alpha'], "delta: ", self.params['delta'])
    
    if plot:
      self.plot_evolution(res, t)

    reward, done = self.get_reward(res, step_counter)

    return self.Xt, reward, done, []


  def plot_evolution(self, res, t):
    
    x, y = res.T
    plt.figure()
    plt.grid()
    plt.title("odeint method")
    plt.plot(t, x, '-b', label = 'Rabbits')
    plt.plot(t, y, '-r', label = "Lynxes")
    plt.xlabel('Time t, [days]')
    plt.ylabel('Population')
    plt.legend()

    plt.show()

    return

# %% [markdown]
# ## Example

# %%
X0 = [100, 10]
params = {'alpha' : 0.55, 'beta' : 0.028,    #'alpha' : 0.55, 'beta' : 0.028,
          'delta' : 0.84,'gamma' : 0.026}    #'delta' : 0.84,'gamma' : 0.026

env = CustomEnv(X0, params, N_ACTIONS)
env.step(1, 0, inplace=True, plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float64
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# alpha:  0.5 delta:  0.75
# (array([15.00472651, 73.81226004]), -1, False, [])

# %%
#To make more steps 
env.step(1, 0, inplace=True, plot=True)
# Out:
# alpha:  0.5 delta:  0.75
# (array([ 3.24719963, 22.5867745 ]), -1000, True, [])

# %% [markdown]
# # Network

# %%
def construct_q_network(N_STATE, N_ACTIONS):
    """Construct the critic network with q-values per action as output"""

    inputs = layers.Input(shape=(N_STATE,))  # input dimension
    hidden1 = layers.Dense(32, activation="relu", kernel_initializer=initializers.he_normal())(inputs)
    hidden2 = layers.Dense(32, activation="relu", kernel_initializer=initializers.he_normal())(hidden1)
    #hidden3 = layers.Dense(32, activation="relu", kernel_initializer=initializers.he_normal())(hidden2)
    #hidden4 = layers.Dense(32, activation="relu", kernel_initializer=initializers.he_normal())(hidden3)
    #hidden5 = layers.Dense(32, activation="relu", kernel_initializer=initializers.he_normal())(hidden4)
    q_values = layers.Dense(N_ACTIONS, activation="linear")(hidden2)

    q_network = keras.Model(inputs=inputs, outputs=[q_values])

    return q_network

# %% [markdown]
# # Deep Q-Learning

# %%
def deepqlearning(sim_input, sim_output, show_plot=False):

    num_episodes = sim_input.num_episodes
    discount = sim_input.discount
    lr = sim_input.lr
    epsilon = sim_input.epsilon

    show_plot = show_plot

    def mean_squared_error_loss(q_value, reward):
        """Compute mean squared error loss"""

        return 0.5 * (q_value - reward) ** 2 

    opt = tf.keras.optimizers.Adam(learning_rate=lr)

    alpha_cache = []
    delta_cache = []
    rewards_cache = np.zeros(num_episodes)

    q_network = construct_q_network(N_STATE, N_ACTIONS*N_ACTIONS)
    target_network = tf.keras.models.clone_model(q_network)  # Copy network architecture
    target_network.set_weights(q_network.get_weights())  # Copy network weights

    replay_buffer = []
    min_buffer_size = 10  # 10
    batch_size = 10
    training = True
    learning_frequency = batch_size  # Set equal to batch size for fair comparisons
    update_frequency_target_network = 10
    states_final_policy = []


    for episode in range(num_episodes):

        step_counter = 0
        done = False

        if not episode % 1:
            print("***** Episode ", episode, " *****")

        # Set to target policy at final episodes
        if episode == len(range(num_episodes)) - 1:
            training = False

        # Initialize environment and agent position
        X0 = np.random.normal([100, 10], [10, 2])
        environment = CustomEnv(X0, params, N_ACTIONS)
        loss_list = []

        while not done:
            with tf.GradientTape() as tape:

                step_counter += 1

                # Get current state
                state = environment.Xt

                if not training:
                  states_final_policy.append([state[0], state[1]])

                # Select action using ε-greedy policy

                # Obtain q-values from network
                q_values = tf.stop_gradient(q_network(state[np.newaxis,:]))

                sample_epsilon = np.random.rand()
                if sample_epsilon <= epsilon and training:
                #if sample_epsilon <= max(epsilon/np.log(episode+2), 0.1) and training:
                    # Select random action
                    action = np.random.choice(N_ACTIONS*N_ACTIONS)
                else:
                    # Select action with highest q-value
                    action = int(np.argmax(q_values[0]))

                # Determine next state
                next_state, reward, done, _ = environment.step(action, step_counter, inplace=True, plot=show_plot, train=training)

                # Compute and store reward
                rewards_cache[episode] += reward

                # Store observation in replay buffer
                observation = [state, action, reward, next_state]
                replay_buffer.append(observation)

                # Update network if (i) buffer sufficiently large and (ii) learning frequency matched and (iii) in training
                if ( len(replay_buffer) >= min_buffer_size
                     and step_counter % learning_frequency == 0
                     and training ):

                    observations = random.choices(replay_buffer, k=batch_size)
                    loss_value = 0

                    # Compute mean loss
                    for observation in observations:
                        state = observation[0]
                        action = observation[1]
                        reward = observation[2]
                        next_state = observation[3]

                        # Select next action with highest q-value
                        # Check whether game is over (ignoring # steps)
                        _ , _, done, _ = environment.step(action, step_counter, inplace=False, plot=False, train = True)
                        
                        if done:
                            next_q_value = 0
                        else:
                            next_q_values = tf.stop_gradient(target_network(next_state[np.newaxis,:]) )
                            next_action = np.argmax(next_q_values[0])
                            next_q_value = next_q_values[0, next_action]

                        observed_q_value = reward + (discount * next_q_value)

                        q_values = q_network(state[np.newaxis,:])
                        current_q_value = q_values[0, action]

                        loss_value += mean_squared_error_loss( observed_q_value, current_q_value )

                    # Compute mean loss value
                    loss_value /= batch_size

                    # Compute gradients
                    grads = tape.gradient(loss_value, q_network.trainable_variables)

                    # Apply gradients to update q-network weights
                    opt.apply_gradients(zip(grads, q_network.trainable_variables))

                    # Periodically update target network
                    if episode % update_frequency_target_network == 0:
                        target_network.set_weights(q_network.get_weights())
                    
                    loss_list.append(loss_value)

                alpha_cache.append(environment.params['alpha'])
                delta_cache.append(environment.params['delta'])
                
                if step_counter >= max_steps:
                  done = True

        print("counter: ", step_counter, '-------', ' loss : ', tf.math.reduce_mean(loss_list))

    sim_output.step_cache.append([alpha_cache, delta_cache])
    sim_output.reward_cache.append(rewards_cache)

    sim_output.env_cache.append(environment)
    sim_output.name_cache.append("Deep Q-learning")

    return q_network, sim_output, states_final_policy, environment

# %% [markdown]
# # Main

# %%
class sim_init:
    def __init__(self, num_episodes, discount, lr, epsilon):
        self.num_episodes = num_episodes  # Number of training episodes
        self.discount = discount          # Discount rate γ 0.9
        self.lr = lr                      # Learning rate α 0.001
        self.epsilon = epsilon            # Exploration rate ε

    def __str__(self):
        return "# episodes: " + str(self.num_episodes) + "gamma: " + str(self.gamma) \
                + "lr: " + str(self.lr) + "epsilon: " + str(self.epsilon)

class sim_output:
    def __init__(self, rewards_cache, step_cache, env_cache, name_cache):
        self.reward_cache = rewards_cache  # list of rewards
        self.step_cache = step_cache       # list of steps
        self.env_cache = env_cache         # list of final paths
        self.name_cache = name_cache       # list of algorithm names

sim_output = sim_output( rewards_cache=[], step_cache=[], env_cache=[], name_cache=[] )

# %%
X0 = [100, 10]
params = {'alpha' : 0.55, 'beta' : 0.028,    #'alpha' : 0.55, 'beta' : 0.028,
          'delta' : 0.84,'gamma' : 0.026}    #'delta' : 0.84,'gamma' : 0.026

# %%
sim_input = sim_init(num_episodes=2000, discount=0.9, lr=0.00001, epsilon=0.1)
q_network, sim_output, states_final_policy, env = deepqlearning(sim_input, sim_output)
# Out:
# ***** Episode  0  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1  *****
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float64
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# counter:  30 -------  loss :  tf.Tensor(33586.816, shape=(), dtype=float32)
# ***** Episode  2  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  3  *****
# counter:  40 -------  loss :  tf.Tensor(37400.76, shape=(), dtype=float32)
# ***** Episode  4  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  5  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  6  *****
# counter:  15 -------  loss :  tf.Tensor(1880.4226, shape=(), dtype=float32)
# ***** Episode  7  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  8  *****
# counter:  30 -------  loss :  tf.Tensor(31729.678, shape=(), dtype=float32)
# ***** Episode  9  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  10  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  11  *****
# counter:  11 -------  loss :  tf.Tensor(2963.349, shape=(), dtype=float32)
# ***** Episode  12  *****
# counter:  20 -------  loss :  tf.Tensor(26982.113, shape=(), dtype=float32)
# ***** Episode  13  *****
# counter:  26 -------  loss :  tf.Tensor(32303.459, shape=(), dtype=float32)
# ***** Episode  14  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  15  *****
# counter:  40 -------  loss :  tf.Tensor(41067.316, shape=(), dtype=float32)
# ***** Episode  16  *****
# counter:  9 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  17  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  18  *****
# counter:  70 -------  loss :  tf.Tensor(18453.363, shape=(), dtype=float32)
# ***** Episode  19  *****
# counter:  27 -------  loss :  tf.Tensor(25527.68, shape=(), dtype=float32)
# ***** Episode  20  *****
# counter:  10 -------  loss :  tf.Tensor(142140.86, shape=(), dtype=float32)
# ***** Episode  21  *****
# counter:  83 -------  loss :  tf.Tensor(33871.848, shape=(), dtype=float32)
# ***** Episode  22  *****
# counter:  84 -------  loss :  tf.Tensor(9119.893, shape=(), dtype=float32)
# ***** Episode  23  *****
# counter:  30 -------  loss :  tf.Tensor(35033.246, shape=(), dtype=float32)
# ***** Episode  24  *****
# counter:  60 -------  loss :  tf.Tensor(17537.596, shape=(), dtype=float32)
# ***** Episode  25  *****
# counter:  29 -------  loss :  tf.Tensor(30055.828, shape=(), dtype=float32)
# ***** Episode  26  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  27  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  28  *****
# counter:  62 -------  loss :  tf.Tensor(10283.663, shape=(), dtype=float32)
# ***** Episode  29  *****
# counter:  12 -------  loss :  tf.Tensor(2059.9937, shape=(), dtype=float32)
# ***** Episode  30  *****
# counter:  17 -------  loss :  tf.Tensor(1591.6168, shape=(), dtype=float32)
# ***** Episode  31  *****
# counter:  30 -------  loss :  tf.Tensor(3887.1162, shape=(), dtype=float32)
# ***** Episode  32  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  33  *****
# counter:  9 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  34  *****
# counter:  18 -------  loss :  tf.Tensor(86386.484, shape=(), dtype=float32)
# ***** Episode  35  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  36  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  37  *****
# counter:  15 -------  loss :  tf.Tensor(37806.15, shape=(), dtype=float32)
# ***** Episode  38  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  39  *****
# counter:  40 -------  loss :  tf.Tensor(12569.502, shape=(), dtype=float32)
# ***** Episode  40  *****
# counter:  10 -------  loss :  tf.Tensor(2479.6157, shape=(), dtype=float32)
# ***** Episode  41  *****
# counter:  10 -------  loss :  tf.Tensor(52439.605, shape=(), dtype=float32)
# ***** Episode  42  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  43  *****
# counter:  38 -------  loss :  tf.Tensor(3342.548, shape=(), dtype=float32)
# ***** Episode  44  *****
# counter:  58 -------  loss :  tf.Tensor(21509.344, shape=(), dtype=float32)
# ***** Episode  45  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  46  *****
# counter:  29 -------  loss :  tf.Tensor(25956.672, shape=(), dtype=float32)
# ***** Episode  47  *****
# counter:  30 -------  loss :  tf.Tensor(63178.926, shape=(), dtype=float32)
# ***** Episode  48  *****
# counter:  1 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  49  *****
# counter:  78 -------  loss :  tf.Tensor(8065.4536, shape=(), dtype=float32)
# ***** Episode  50  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  51  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  52  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  53  *****
# counter:  29 -------  loss :  tf.Tensor(31012.445, shape=(), dtype=float32)
# ***** Episode  54  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  55  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  56  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  57  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  58  *****
# counter:  39 -------  loss :  tf.Tensor(41322.2, shape=(), dtype=float32)
# ***** Episode  59  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  60  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  61  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  62  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  63  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  64  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  65  *****
# counter:  72 -------  loss :  tf.Tensor(20434.459, shape=(), dtype=float32)
# ***** Episode  66  *****
# counter:  44 -------  loss :  tf.Tensor(14589.962, shape=(), dtype=float32)
# ***** Episode  67  *****
# counter:  88 -------  loss :  tf.Tensor(12725.74, shape=(), dtype=float32)
# ***** Episode  68  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  69  *****
# counter:  9 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  70  *****
# counter:  40 -------  loss :  tf.Tensor(2838.9224, shape=(), dtype=float32)
# ***** Episode  71  *****
# counter:  16 -------  loss :  tf.Tensor(2027.4978, shape=(), dtype=float32)
# ***** Episode  72  *****
# counter:  70 -------  loss :  tf.Tensor(42721.906, shape=(), dtype=float32)
# ***** Episode  73  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  74  *****
# counter:  13 -------  loss :  tf.Tensor(55812.074, shape=(), dtype=float32)
# ***** Episode  75  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  76  *****
# counter:  18 -------  loss :  tf.Tensor(5533.022, shape=(), dtype=float32)
# ***** Episode  77  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  78  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  79  *****
# counter:  10 -------  loss :  tf.Tensor(4206.0737, shape=(), dtype=float32)
# ***** Episode  80  *****
# counter:  19 -------  loss :  tf.Tensor(2106.0151, shape=(), dtype=float32)
# ***** Episode  81  *****
# counter:  32 -------  loss :  tf.Tensor(17534.654, shape=(), dtype=float32)
# ***** Episode  82  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  83  *****
# counter:  56 -------  loss :  tf.Tensor(24710.605, shape=(), dtype=float32)
# ***** Episode  84  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  85  *****
# counter:  10 -------  loss :  tf.Tensor(6184.5317, shape=(), dtype=float32)
# ***** Episode  86  *****
# counter:  85 -------  loss :  tf.Tensor(24876.396, shape=(), dtype=float32)
# ***** Episode  87  *****
# counter:  72 -------  loss :  tf.Tensor(17184.443, shape=(), dtype=float32)
# ***** Episode  88  *****
# counter:  19 -------  loss :  tf.Tensor(49109.8, shape=(), dtype=float32)
# ***** Episode  89  *****
# counter:  79 -------  loss :  tf.Tensor(13217.604, shape=(), dtype=float32)
# ***** Episode  90  *****
# counter:  31 -------  loss :  tf.Tensor(69462.82, shape=(), dtype=float32)
# ***** Episode  91  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  92  *****
# counter:  14 -------  loss :  tf.Tensor(98150.05, shape=(), dtype=float32)
# ***** Episode  93  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  94  *****
# counter:  67 -------  loss :  tf.Tensor(28078.328, shape=(), dtype=float32)
# ***** Episode  95  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  96  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  97  *****
# counter:  13 -------  loss :  tf.Tensor(1790.237, shape=(), dtype=float32)
# ***** Episode  98  *****
# counter:  45 -------  loss :  tf.Tensor(1583.6775, shape=(), dtype=float32)
# ***** Episode  99  *****
# counter:  70 -------  loss :  tf.Tensor(27812.936, shape=(), dtype=float32)
# ***** Episode  100  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  101  *****
# counter:  43 -------  loss :  tf.Tensor(64119.906, shape=(), dtype=float32)
# ***** Episode  102  *****
# counter:  10 -------  loss :  tf.Tensor(57157.305, shape=(), dtype=float32)
# ***** Episode  103  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  104  *****
# counter:  23 -------  loss :  tf.Tensor(20214.318, shape=(), dtype=float32)
# ***** Episode  105  *****
# counter:  9 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  106  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  107  *****
# counter:  47 -------  loss :  tf.Tensor(24614.963, shape=(), dtype=float32)
# ***** Episode  108  *****
# counter:  16 -------  loss :  tf.Tensor(1528.251, shape=(), dtype=float32)
# ***** Episode  109  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  110  *****
# counter:  17 -------  loss :  tf.Tensor(89395.195, shape=(), dtype=float32)
# ***** Episode  111  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  112  *****
# counter:  35 -------  loss :  tf.Tensor(48331.785, shape=(), dtype=float32)
# ***** Episode  113  *****
# counter:  20 -------  loss :  tf.Tensor(28867.643, shape=(), dtype=float32)
# ***** Episode  114  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  115  *****
# counter:  14 -------  loss :  tf.Tensor(1113.9401, shape=(), dtype=float32)
# ***** Episode  116  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  117  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  118  *****
# counter:  18 -------  loss :  tf.Tensor(1236.7405, shape=(), dtype=float32)
# ***** Episode  119  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  120  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  121  *****
# counter:  10 -------  loss :  tf.Tensor(3312.5215, shape=(), dtype=float32)
# ***** Episode  122  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  123  *****
# counter:  1 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  124  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  125  *****
# counter:  10 -------  loss :  tf.Tensor(42329.78, shape=(), dtype=float32)
# ***** Episode  126  *****
# counter:  25 -------  loss :  tf.Tensor(1878.1428, shape=(), dtype=float32)
# ***** Episode  127  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  128  *****
# counter:  9 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  129  *****
# counter:  22 -------  loss :  tf.Tensor(26356.627, shape=(), dtype=float32)
# ***** Episode  130  *****
# counter:  13 -------  loss :  tf.Tensor(275.5716, shape=(), dtype=float32)
# ***** Episode  131  *****
# counter:  38 -------  loss :  tf.Tensor(15705.759, shape=(), dtype=float32)
# ***** Episode  132  *****
# counter:  13 -------  loss :  tf.Tensor(87380.64, shape=(), dtype=float32)
# ***** Episode  133  *****
# counter:  10 -------  loss :  tf.Tensor(44721.19, shape=(), dtype=float32)
# ***** Episode  134  *****
# counter:  10 -------  loss :  tf.Tensor(4698.121, shape=(), dtype=float32)
# ***** Episode  135  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  136  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  137  *****
# counter:  25 -------  loss :  tf.Tensor(28966.766, shape=(), dtype=float32)
# ***** Episode  138  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  139  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  140  *****
# counter:  30 -------  loss :  tf.Tensor(19329.887, shape=(), dtype=float32)
# ***** Episode  141  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  142  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  143  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  144  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  145  *****
# counter:  20 -------  loss :  tf.Tensor(73578.45, shape=(), dtype=float32)
# ***** Episode  146  *****
# counter:  26 -------  loss :  tf.Tensor(25067.947, shape=(), dtype=float32)
# ***** Episode  147  *****
# counter:  21 -------  loss :  tf.Tensor(28574.092, shape=(), dtype=float32)
# ***** Episode  148  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  149  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  150  *****
# counter:  120 -------  loss :  tf.Tensor(34490.723, shape=(), dtype=float32)
# ***** Episode  151  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  152  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  153  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  154  *****
# counter:  20 -------  loss :  tf.Tensor(46957.383, shape=(), dtype=float32)
# ***** Episode  155  *****
# counter:  27 -------  loss :  tf.Tensor(2157.594, shape=(), dtype=float32)
# ***** Episode  156  *****
# counter:  5 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  157  *****
# counter:  20 -------  loss :  tf.Tensor(27938.709, shape=(), dtype=float32)
# ***** Episode  158  *****
# counter:  10 -------  loss :  tf.Tensor(3603.6934, shape=(), dtype=float32)
# ***** Episode  159  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  160  *****
# counter:  12 -------  loss :  tf.Tensor(2991.411, shape=(), dtype=float32)
# ***** Episode  161  *****
# counter:  35 -------  loss :  tf.Tensor(51191.613, shape=(), dtype=float32)
# ***** Episode  162  *****
# counter:  23 -------  loss :  tf.Tensor(1990.458, shape=(), dtype=float32)
# ***** Episode  163  *****
# counter:  10 -------  loss :  tf.Tensor(3056.5518, shape=(), dtype=float32)
# ***** Episode  164  *****
# counter:  23 -------  loss :  tf.Tensor(23175.621, shape=(), dtype=float32)
# ***** Episode  165  *****
# counter:  10 -------  loss :  tf.Tensor(5074.542, shape=(), dtype=float32)
# ***** Episode  166  *****
# counter:  30 -------  loss :  tf.Tensor(39764.27, shape=(), dtype=float32)
# ***** Episode  167  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  168  *****
# counter:  17 -------  loss :  tf.Tensor(49927.223, shape=(), dtype=float32)
# ***** Episode  169  *****
# counter:  48 -------  loss :  tf.Tensor(32593.785, shape=(), dtype=float32)
# ***** Episode  170  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  171  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  172  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  173  *****
# counter:  23 -------  loss :  tf.Tensor(24251.639, shape=(), dtype=float32)
# ***** Episode  174  *****
# counter:  35 -------  loss :  tf.Tensor(1214.702, shape=(), dtype=float32)
# ***** Episode  175  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  176  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  177  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  178  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  179  *****
# counter:  18 -------  loss :  tf.Tensor(49987.934, shape=(), dtype=float32)
# ***** Episode  180  *****
# counter:  50 -------  loss :  tf.Tensor(2935.431, shape=(), dtype=float32)
# ***** Episode  181  *****
# counter:  34 -------  loss :  tf.Tensor(1437.016, shape=(), dtype=float32)
# ***** Episode  182  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  183  *****
# counter:  51 -------  loss :  tf.Tensor(31234.291, shape=(), dtype=float32)
# ***** Episode  184  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  185  *****
# counter:  27 -------  loss :  tf.Tensor(56732.805, shape=(), dtype=float32)
# ***** Episode  186  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  187  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  188  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  189  *****
# counter:  19 -------  loss :  tf.Tensor(1359.4275, shape=(), dtype=float32)
# ***** Episode  190  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  191  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  192  *****
# counter:  10 -------  loss :  tf.Tensor(6643.741, shape=(), dtype=float32)
# ***** Episode  193  *****
# counter:  15 -------  loss :  tf.Tensor(40574.344, shape=(), dtype=float32)
# ***** Episode  194  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  195  *****
# counter:  10 -------  loss :  tf.Tensor(2859.7607, shape=(), dtype=float32)
# ***** Episode  196  *****
# counter:  29 -------  loss :  tf.Tensor(24019.266, shape=(), dtype=float32)
# ***** Episode  197  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  198  *****
# counter:  15 -------  loss :  tf.Tensor(1193.6454, shape=(), dtype=float32)
# ***** Episode  199  *****
# counter:  10 -------  loss :  tf.Tensor(53414.5, shape=(), dtype=float32)
# ***** Episode  200  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  201  *****
# counter:  20 -------  loss :  tf.Tensor(29903.113, shape=(), dtype=float32)
# ***** Episode  202  *****
# counter:  56 -------  loss :  tf.Tensor(41363.44, shape=(), dtype=float32)
# ***** Episode  203  *****
# counter:  33 -------  loss :  tf.Tensor(15093.116, shape=(), dtype=float32)
# ***** Episode  204  *****
# counter:  11 -------  loss :  tf.Tensor(3429.9292, shape=(), dtype=float32)
# ***** Episode  205  *****
# counter:  65 -------  loss :  tf.Tensor(24208.857, shape=(), dtype=float32)
# ***** Episode  206  *****
# counter:  18 -------  loss :  tf.Tensor(1268.3071, shape=(), dtype=float32)
# ***** Episode  207  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  208  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  209  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  210  *****
# counter:  93 -------  loss :  tf.Tensor(12416.768, shape=(), dtype=float32)
# ***** Episode  211  *****
# counter:  29 -------  loss :  tf.Tensor(27629.945, shape=(), dtype=float32)
# ***** Episode  212  *****
# counter:  20 -------  loss :  tf.Tensor(82148.984, shape=(), dtype=float32)
# ***** Episode  213  *****
# counter:  9 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  214  *****
# counter:  10 -------  loss :  tf.Tensor(3784.1538, shape=(), dtype=float32)
# ***** Episode  215  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  216  *****
# counter:  36 -------  loss :  tf.Tensor(44568.906, shape=(), dtype=float32)
# ***** Episode  217  *****
# counter:  20 -------  loss :  tf.Tensor(52398.53, shape=(), dtype=float32)
# ***** Episode  218  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  219  *****
# counter:  29 -------  loss :  tf.Tensor(23606.75, shape=(), dtype=float32)
# ***** Episode  220  *****
# counter:  60 -------  loss :  tf.Tensor(2237.7876, shape=(), dtype=float32)
# ***** Episode  221  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  222  *****
# counter:  57 -------  loss :  tf.Tensor(22817.902, shape=(), dtype=float32)
# ***** Episode  223  *****
# counter:  32 -------  loss :  tf.Tensor(46575.56, shape=(), dtype=float32)
# ***** Episode  224  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  225  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  226  *****
# counter:  26 -------  loss :  tf.Tensor(27406.44, shape=(), dtype=float32)
# ***** Episode  227  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  228  *****
# counter:  39 -------  loss :  tf.Tensor(34297.844, shape=(), dtype=float32)
# ***** Episode  229  *****
# counter:  29 -------  loss :  tf.Tensor(3661.6035, shape=(), dtype=float32)
# ***** Episode  230  *****
# counter:  70 -------  loss :  tf.Tensor(3096.3972, shape=(), dtype=float32)
# ***** Episode  231  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  232  *****
# counter:  28 -------  loss :  tf.Tensor(27129.293, shape=(), dtype=float32)
# ***** Episode  233  *****
# counter:  15 -------  loss :  tf.Tensor(2630.4949, shape=(), dtype=float32)
# ***** Episode  234  *****
# counter:  19 -------  loss :  tf.Tensor(1902.706, shape=(), dtype=float32)
# ***** Episode  235  *****
# counter:  10 -------  loss :  tf.Tensor(4009.9363, shape=(), dtype=float32)
# ***** Episode  236  *****
# counter:  20 -------  loss :  tf.Tensor(26875.629, shape=(), dtype=float32)
# ***** Episode  237  *****
# counter:  10 -------  loss :  tf.Tensor(49477.77, shape=(), dtype=float32)
# ***** Episode  238  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  239  *****
# counter:  10 -------  loss :  tf.Tensor(10166.39, shape=(), dtype=float32)
# ***** Episode  240  *****
# counter:  20 -------  loss :  tf.Tensor(2738.1155, shape=(), dtype=float32)
# ***** Episode  241  *****
# counter:  82 -------  loss :  tf.Tensor(7115.9595, shape=(), dtype=float32)
# ***** Episode  242  *****
# counter:  9 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  243  *****
# counter:  20 -------  loss :  tf.Tensor(3718.224, shape=(), dtype=float32)
# ***** Episode  244  *****
# counter:  20 -------  loss :  tf.Tensor(4907.0757, shape=(), dtype=float32)
# ***** Episode  245  *****
# counter:  34 -------  loss :  tf.Tensor(54282.734, shape=(), dtype=float32)
# ***** Episode  246  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  247  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  248  *****
# counter:  61 -------  loss :  tf.Tensor(15450.673, shape=(), dtype=float32)
# ***** Episode  249  *****
# counter:  20 -------  loss :  tf.Tensor(64764.145, shape=(), dtype=float32)
# ***** Episode  250  *****
# counter:  10 -------  loss :  tf.Tensor(4555.671, shape=(), dtype=float32)
# ***** Episode  251  *****
# counter:  51 -------  loss :  tf.Tensor(29411.354, shape=(), dtype=float32)
# ***** Episode  252  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  253  *****
# counter:  23 -------  loss :  tf.Tensor(1777.8672, shape=(), dtype=float32)
# ***** Episode  254  *****
# counter:  86 -------  loss :  tf.Tensor(26313.203, shape=(), dtype=float32)
# ***** Episode  255  *****
# counter:  20 -------  loss :  tf.Tensor(32186.969, shape=(), dtype=float32)
# ***** Episode  256  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  257  *****
# counter:  52 -------  loss :  tf.Tensor(19419.7, shape=(), dtype=float32)
# ***** Episode  258  *****
# counter:  10 -------  loss :  tf.Tensor(59206.887, shape=(), dtype=float32)
# ***** Episode  259  *****
# counter:  34 -------  loss :  tf.Tensor(13413.434, shape=(), dtype=float32)
# ***** Episode  260  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  261  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  262  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  263  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  264  *****
# counter:  19 -------  loss :  tf.Tensor(40970.367, shape=(), dtype=float32)
# ***** Episode  265  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  266  *****
# counter:  23 -------  loss :  tf.Tensor(26740.51, shape=(), dtype=float32)
# ***** Episode  267  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  268  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  269  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  270  *****
# counter:  21 -------  loss :  tf.Tensor(1721.9473, shape=(), dtype=float32)
# ***** Episode  271  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  272  *****
# counter:  10 -------  loss :  tf.Tensor(5276.3447, shape=(), dtype=float32)
# ***** Episode  273  *****
# counter:  25 -------  loss :  tf.Tensor(77691.58, shape=(), dtype=float32)
# ***** Episode  274  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  275  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  276  *****
# counter:  12 -------  loss :  tf.Tensor(953.95886, shape=(), dtype=float32)
# ***** Episode  277  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  278  *****
# counter:  12 -------  loss :  tf.Tensor(1947.7988, shape=(), dtype=float32)
# ***** Episode  279  *****
# counter:  23 -------  loss :  tf.Tensor(2775.194, shape=(), dtype=float32)
# ***** Episode  280  *****
# counter:  5 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  281  *****
# counter:  47 -------  loss :  tf.Tensor(24590.4, shape=(), dtype=float32)
# ***** Episode  282  *****
# counter:  25 -------  loss :  tf.Tensor(24596.412, shape=(), dtype=float32)
# ***** Episode  283  *****
# counter:  16 -------  loss :  tf.Tensor(86255.23, shape=(), dtype=float32)
# ***** Episode  284  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  285  *****
# counter:  12 -------  loss :  tf.Tensor(400.7098, shape=(), dtype=float32)
# ***** Episode  286  *****
# counter:  30 -------  loss :  tf.Tensor(37101.797, shape=(), dtype=float32)
# ***** Episode  287  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  288  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  289  *****
# counter:  17 -------  loss :  tf.Tensor(1570.3484, shape=(), dtype=float32)
# ***** Episode  290  *****
# counter:  26 -------  loss :  tf.Tensor(47521.555, shape=(), dtype=float32)
# ***** Episode  291  *****
# counter:  10 -------  loss :  tf.Tensor(4413.302, shape=(), dtype=float32)
# ***** Episode  292  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  293  *****
# counter:  13 -------  loss :  tf.Tensor(43914.027, shape=(), dtype=float32)
# ***** Episode  294  *****
# counter:  23 -------  loss :  tf.Tensor(43265.305, shape=(), dtype=float32)
# ***** Episode  295  *****
# counter:  11 -------  loss :  tf.Tensor(42634.69, shape=(), dtype=float32)
# ***** Episode  296  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  297  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  298  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  299  *****
# counter:  33 -------  loss :  tf.Tensor(23207.469, shape=(), dtype=float32)
# ***** Episode  300  *****
# counter:  10 -------  loss :  tf.Tensor(46247.992, shape=(), dtype=float32)
# ***** Episode  301  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  302  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  303  *****
# counter:  20 -------  loss :  tf.Tensor(29263.762, shape=(), dtype=float32)
# ***** Episode  304  *****
# counter:  10 -------  loss :  tf.Tensor(6256.73, shape=(), dtype=float32)
# ***** Episode  305  *****
# counter:  70 -------  loss :  tf.Tensor(15926.106, shape=(), dtype=float32)
# ***** Episode  306  *****
# counter:  36 -------  loss :  tf.Tensor(80816.76, shape=(), dtype=float32)
# ***** Episode  307  *****
# counter:  11 -------  loss :  tf.Tensor(53358.617, shape=(), dtype=float32)
# ***** Episode  308  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  309  *****
# counter:  17 -------  loss :  tf.Tensor(3772.3828, shape=(), dtype=float32)
# ***** Episode  310  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  311  *****
# counter:  38 -------  loss :  tf.Tensor(1494.4723, shape=(), dtype=float32)
# ***** Episode  312  *****
# counter:  39 -------  loss :  tf.Tensor(1474.8853, shape=(), dtype=float32)
# ***** Episode  313  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  314  *****
# counter:  18 -------  loss :  tf.Tensor(1423.5144, shape=(), dtype=float32)
# ***** Episode  315  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  316  *****
# counter:  19 -------  loss :  tf.Tensor(5195.27, shape=(), dtype=float32)
# ***** Episode  317  *****
# counter:  1 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  318  *****
# counter:  9 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  319  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  320  *****
# counter:  12 -------  loss :  tf.Tensor(2938.9387, shape=(), dtype=float32)
# ***** Episode  321  *****
# counter:  51 -------  loss :  tf.Tensor(9528.13, shape=(), dtype=float32)
# ***** Episode  322  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  323  *****
# counter:  5 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  324  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  325  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  326  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  327  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  328  *****
# counter:  23 -------  loss :  tf.Tensor(1513.3545, shape=(), dtype=float32)
# ***** Episode  329  *****
# counter:  20 -------  loss :  tf.Tensor(2361.0444, shape=(), dtype=float32)
# ***** Episode  330  *****
# counter:  22 -------  loss :  tf.Tensor(953.8201, shape=(), dtype=float32)
# ***** Episode  331  *****
# counter:  28 -------  loss :  tf.Tensor(2400.689, shape=(), dtype=float32)
# ***** Episode  332  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  333  *****
# counter:  43 -------  loss :  tf.Tensor(34430.637, shape=(), dtype=float32)
# ***** Episode  334  *****
# counter:  30 -------  loss :  tf.Tensor(1439.226, shape=(), dtype=float32)
# ***** Episode  335  *****
# counter:  25 -------  loss :  tf.Tensor(52162.04, shape=(), dtype=float32)
# ***** Episode  336  *****
# counter:  51 -------  loss :  tf.Tensor(1098.864, shape=(), dtype=float32)
# ***** Episode  337  *****
# counter:  10 -------  loss :  tf.Tensor(6202.3027, shape=(), dtype=float32)
# ***** Episode  338  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  339  *****
# counter:  18 -------  loss :  tf.Tensor(1399.0583, shape=(), dtype=float32)
# ***** Episode  340  *****
# counter:  33 -------  loss :  tf.Tensor(14217.251, shape=(), dtype=float32)
# ***** Episode  341  *****
# counter:  10 -------  loss :  tf.Tensor(2605.0254, shape=(), dtype=float32)
# ***** Episode  342  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  343  *****
# counter:  20 -------  loss :  tf.Tensor(23465.924, shape=(), dtype=float32)
# ***** Episode  344  *****
# counter:  5 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  345  *****
# counter:  70 -------  loss :  tf.Tensor(29805.723, shape=(), dtype=float32)
# ***** Episode  346  *****
# counter:  9 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  347  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  348  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  349  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  350  *****
# counter:  39 -------  loss :  tf.Tensor(55170.86, shape=(), dtype=float32)
# ***** Episode  351  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  352  *****
# counter:  66 -------  loss :  tf.Tensor(14854.933, shape=(), dtype=float32)
# ***** Episode  353  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  354  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  355  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  356  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  357  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  358  *****
# counter:  38 -------  loss :  tf.Tensor(17764.691, shape=(), dtype=float32)
# ***** Episode  359  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  360  *****
# counter:  24 -------  loss :  tf.Tensor(1180.0814, shape=(), dtype=float32)
# ***** Episode  361  *****
# counter:  5 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  362  *****
# counter:  22 -------  loss :  tf.Tensor(1522.5176, shape=(), dtype=float32)
# ***** Episode  363  *****
# counter:  38 -------  loss :  tf.Tensor(1974.066, shape=(), dtype=float32)
# ***** Episode  364  *****
# counter:  1 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  365  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  366  *****
# counter:  10 -------  loss :  tf.Tensor(192589.22, shape=(), dtype=float32)
# ***** Episode  367  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  368  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  369  *****
# counter:  20 -------  loss :  tf.Tensor(28182.523, shape=(), dtype=float32)
# ***** Episode  370  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  371  *****
# counter:  10 -------  loss :  tf.Tensor(3781.002, shape=(), dtype=float32)
# ***** Episode  372  *****
# counter:  25 -------  loss :  tf.Tensor(70379.08, shape=(), dtype=float32)
# ***** Episode  373  *****
# counter:  1 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  374  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  375  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  376  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  377  *****
# counter:  40 -------  loss :  tf.Tensor(47238.492, shape=(), dtype=float32)
# ***** Episode  378  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  379  *****
# counter:  10 -------  loss :  tf.Tensor(5343.322, shape=(), dtype=float32)
# ***** Episode  380  *****
# counter:  23 -------  loss :  tf.Tensor(4512.421, shape=(), dtype=float32)
# ***** Episode  381  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  382  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  383  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  384  *****
# counter:  32 -------  loss :  tf.Tensor(41249.81, shape=(), dtype=float32)
# ***** Episode  385  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  386  *****
# counter:  33 -------  loss :  tf.Tensor(18124.066, shape=(), dtype=float32)
# ***** Episode  387  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  388  *****
# counter:  14 -------  loss :  tf.Tensor(49448.66, shape=(), dtype=float32)
# ***** Episode  389  *****
# counter:  35 -------  loss :  tf.Tensor(41482.746, shape=(), dtype=float32)
# ***** Episode  390  *****
# counter:  18 -------  loss :  tf.Tensor(2907.9185, shape=(), dtype=float32)
# ***** Episode  391  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  392  *****
# counter:  29 -------  loss :  tf.Tensor(2270.851, shape=(), dtype=float32)
# ***** Episode  393  *****
# counter:  24 -------  loss :  tf.Tensor(1739.6589, shape=(), dtype=float32)
# ***** Episode  394  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  395  *****
# counter:  9 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  396  *****
# counter:  14 -------  loss :  tf.Tensor(48869.176, shape=(), dtype=float32)
# ***** Episode  397  *****
# counter:  42 -------  loss :  tf.Tensor(35422.805, shape=(), dtype=float32)
# ***** Episode  398  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  399  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  400  *****
# counter:  5 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  401  *****
# counter:  14 -------  loss :  tf.Tensor(1536.5538, shape=(), dtype=float32)
# ***** Episode  402  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  403  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  404  *****
# counter:  16 -------  loss :  tf.Tensor(47115.117, shape=(), dtype=float32)
# ***** Episode  405  *****
# counter:  20 -------  loss :  tf.Tensor(43663.31, shape=(), dtype=float32)
# ***** Episode  406  *****
# counter:  9 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  407  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  408  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  409  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  410  *****
# counter:  20 -------  loss :  tf.Tensor(61560.92, shape=(), dtype=float32)
# ***** Episode  411  *****
# counter:  24 -------  loss :  tf.Tensor(889.77075, shape=(), dtype=float32)
# ***** Episode  412  *****
# counter:  10 -------  loss :  tf.Tensor(3784.9946, shape=(), dtype=float32)
# ***** Episode  413  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  414  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  415  *****
# counter:  24 -------  loss :  tf.Tensor(1469.0859, shape=(), dtype=float32)
# ***** Episode  416  *****
# counter:  46 -------  loss :  tf.Tensor(8239.589, shape=(), dtype=float32)
# ***** Episode  417  *****
# counter:  26 -------  loss :  tf.Tensor(1910.8718, shape=(), dtype=float32)
# ***** Episode  418  *****
# counter:  1 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  419  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  420  *****
# counter:  11 -------  loss :  tf.Tensor(1797.0596, shape=(), dtype=float32)
# ***** Episode  421  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  422  *****
# counter:  35 -------  loss :  tf.Tensor(12724.059, shape=(), dtype=float32)
# ***** Episode  423  *****
# counter:  37 -------  loss :  tf.Tensor(29076.771, shape=(), dtype=float32)
# ***** Episode  424  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  425  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  426  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  427  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  428  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  429  *****
# counter:  30 -------  loss :  tf.Tensor(65148.06, shape=(), dtype=float32)
# ***** Episode  430  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  431  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  432  *****
# counter:  10 -------  loss :  tf.Tensor(4720.48, shape=(), dtype=float32)
# ***** Episode  433  *****
# counter:  40 -------  loss :  tf.Tensor(26242.67, shape=(), dtype=float32)
# ***** Episode  434  *****
# counter:  16 -------  loss :  tf.Tensor(2572.1924, shape=(), dtype=float32)
# ***** Episode  435  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  436  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  437  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  438  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  439  *****
# counter:  9 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  440  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  441  *****
# counter:  10 -------  loss :  tf.Tensor(54759.57, shape=(), dtype=float32)
# ***** Episode  442  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  443  *****
# counter:  10 -------  loss :  tf.Tensor(53185.426, shape=(), dtype=float32)
# ***** Episode  444  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  445  *****
# counter:  16 -------  loss :  tf.Tensor(37305.895, shape=(), dtype=float32)
# ***** Episode  446  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  447  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  448  *****
# counter:  10 -------  loss :  tf.Tensor(3864.5894, shape=(), dtype=float32)
# ***** Episode  449  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  450  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  451  *****
# counter:  19 -------  loss :  tf.Tensor(2203.211, shape=(), dtype=float32)
# ***** Episode  452  *****
# counter:  15 -------  loss :  tf.Tensor(1938.4944, shape=(), dtype=float32)
# ***** Episode  453  *****
# counter:  1 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  454  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  455  *****
# counter:  40 -------  loss :  tf.Tensor(12925.262, shape=(), dtype=float32)
# ***** Episode  456  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  457  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  458  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  459  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  460  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  461  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  462  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  463  *****
# counter:  10 -------  loss :  tf.Tensor(105464.71, shape=(), dtype=float32)
# ***** Episode  464  *****
# counter:  5 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  465  *****
# counter:  1 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  466  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  467  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  468  *****
# counter:  32 -------  loss :  tf.Tensor(33175.965, shape=(), dtype=float32)
# ***** Episode  469  *****
# counter:  10 -------  loss :  tf.Tensor(3623.2, shape=(), dtype=float32)
# ***** Episode  470  *****
# counter:  32 -------  loss :  tf.Tensor(1851.3842, shape=(), dtype=float32)
# ***** Episode  471  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  472  *****
# counter:  5 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  473  *****
# counter:  10 -------  loss :  tf.Tensor(3218.1077, shape=(), dtype=float32)
# ***** Episode  474  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  475  *****
# counter:  47 -------  loss :  tf.Tensor(26042.951, shape=(), dtype=float32)
# ***** Episode  476  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  477  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  478  *****
# counter:  5 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  479  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  480  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  481  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  482  *****
# counter:  109 -------  loss :  tf.Tensor(33980.14, shape=(), dtype=float32)
# ***** Episode  483  *****
# counter:  56 -------  loss :  tf.Tensor(38959.926, shape=(), dtype=float32)
# ***** Episode  484  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  485  *****
# counter:  17 -------  loss :  tf.Tensor(1508.9795, shape=(), dtype=float32)
# ***** Episode  486  *****
# ...
# ***** Episode  1891  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1892  *****
# counter:  57 -------  loss :  tf.Tensor(727.7576, shape=(), dtype=float32)
# ***** Episode  1893  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1894  *****
# counter:  59 -------  loss :  tf.Tensor(18481.28, shape=(), dtype=float32)
# ***** Episode  1895  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1896  *****
# counter:  30 -------  loss :  tf.Tensor(33466.656, shape=(), dtype=float32)
# ***** Episode  1897  *****
# counter:  10 -------  loss :  tf.Tensor(54271.78, shape=(), dtype=float32)
# ***** Episode  1898  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1899  *****
# counter:  9 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1900  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1901  *****
# counter:  43 -------  loss :  tf.Tensor(46051.164, shape=(), dtype=float32)
# ***** Episode  1902  *****
# counter:  10 -------  loss :  tf.Tensor(2447.1711, shape=(), dtype=float32)
# ***** Episode  1903  *****
# counter:  14 -------  loss :  tf.Tensor(1979.7854, shape=(), dtype=float32)
# ***** Episode  1904  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1905  *****
# counter:  30 -------  loss :  tf.Tensor(22518.139, shape=(), dtype=float32)
# ***** Episode  1906  *****
# counter:  10 -------  loss :  tf.Tensor(1990.6547, shape=(), dtype=float32)
# ***** Episode  1907  *****
# counter:  10 -------  loss :  tf.Tensor(2850.4402, shape=(), dtype=float32)
# ***** Episode  1908  *****
# counter:  12 -------  loss :  tf.Tensor(39050.7, shape=(), dtype=float32)
# ***** Episode  1909  *****
# counter:  10 -------  loss :  tf.Tensor(55695.055, shape=(), dtype=float32)
# ***** Episode  1910  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1911  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1912  *****
# counter:  50 -------  loss :  tf.Tensor(24313.121, shape=(), dtype=float32)
# ***** Episode  1913  *****
# counter:  10 -------  loss :  tf.Tensor(3130.3872, shape=(), dtype=float32)
# ***** Episode  1914  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1915  *****
# counter:  18 -------  loss :  tf.Tensor(87079.71, shape=(), dtype=float32)
# ***** Episode  1916  *****
# counter:  12 -------  loss :  tf.Tensor(1392.5955, shape=(), dtype=float32)
# ***** Episode  1917  *****
# counter:  68 -------  loss :  tf.Tensor(24837.256, shape=(), dtype=float32)
# ***** Episode  1918  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1919  *****
# counter:  19 -------  loss :  tf.Tensor(44787.18, shape=(), dtype=float32)
# ***** Episode  1920  *****
# counter:  48 -------  loss :  tf.Tensor(14416.8, shape=(), dtype=float32)
# ***** Episode  1921  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1922  *****
# counter:  36 -------  loss :  tf.Tensor(1175.5975, shape=(), dtype=float32)
# ***** Episode  1923  *****
# counter:  10 -------  loss :  tf.Tensor(54140.727, shape=(), dtype=float32)
# ***** Episode  1924  *****
# counter:  37 -------  loss :  tf.Tensor(14913.707, shape=(), dtype=float32)
# ***** Episode  1925  *****
# counter:  54 -------  loss :  tf.Tensor(13299.394, shape=(), dtype=float32)
# ***** Episode  1926  *****
# counter:  10 -------  loss :  tf.Tensor(2813.4048, shape=(), dtype=float32)
# ***** Episode  1927  *****
# counter:  58 -------  loss :  tf.Tensor(20851.98, shape=(), dtype=float32)
# ***** Episode  1928  *****
# counter:  17 -------  loss :  tf.Tensor(1093.2131, shape=(), dtype=float32)
# ***** Episode  1929  *****
# counter:  5 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1930  *****
# counter:  15 -------  loss :  tf.Tensor(617.8273, shape=(), dtype=float32)
# ***** Episode  1931  *****
# counter:  26 -------  loss :  tf.Tensor(24894.307, shape=(), dtype=float32)
# ***** Episode  1932  *****
# counter:  22 -------  loss :  tf.Tensor(28238.93, shape=(), dtype=float32)
# ***** Episode  1933  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1934  *****
# counter:  12 -------  loss :  tf.Tensor(408.93607, shape=(), dtype=float32)
# ***** Episode  1935  *****
# counter:  39 -------  loss :  tf.Tensor(16061.458, shape=(), dtype=float32)
# ***** Episode  1936  *****
# counter:  20 -------  loss :  tf.Tensor(2379.8376, shape=(), dtype=float32)
# ***** Episode  1937  *****
# counter:  29 -------  loss :  tf.Tensor(46846.203, shape=(), dtype=float32)
# ***** Episode  1938  *****
# counter:  10 -------  loss :  tf.Tensor(1053.3256, shape=(), dtype=float32)
# ***** Episode  1939  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1940  *****
# counter:  3 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1941  *****
# counter:  24 -------  loss :  tf.Tensor(29087.953, shape=(), dtype=float32)
# ***** Episode  1942  *****
# counter:  27 -------  loss :  tf.Tensor(49807.094, shape=(), dtype=float32)
# ***** Episode  1943  *****
# counter:  44 -------  loss :  tf.Tensor(14360.349, shape=(), dtype=float32)
# ***** Episode  1944  *****
# counter:  58 -------  loss :  tf.Tensor(38671.867, shape=(), dtype=float32)
# ***** Episode  1945  *****
# counter:  10 -------  loss :  tf.Tensor(106834.42, shape=(), dtype=float32)
# ***** Episode  1946  *****
# counter:  5 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1947  *****
# counter:  17 -------  loss :  tf.Tensor(1373.0856, shape=(), dtype=float32)
# ***** Episode  1948  *****
# counter:  10 -------  loss :  tf.Tensor(2813.0254, shape=(), dtype=float32)
# ***** Episode  1949  *****
# counter:  12 -------  loss :  tf.Tensor(130762.98, shape=(), dtype=float32)
# ***** Episode  1950  *****
# counter:  18 -------  loss :  tf.Tensor(57482.79, shape=(), dtype=float32)
# ***** Episode  1951  *****
# counter:  44 -------  loss :  tf.Tensor(1216.4076, shape=(), dtype=float32)
# ***** Episode  1952  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1953  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1954  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1955  *****
# counter:  46 -------  loss :  tf.Tensor(13423.937, shape=(), dtype=float32)
# ***** Episode  1956  *****
# counter:  16 -------  loss :  tf.Tensor(1840.5403, shape=(), dtype=float32)
# ***** Episode  1957  *****
# counter:  36 -------  loss :  tf.Tensor(33904.195, shape=(), dtype=float32)
# ***** Episode  1958  *****
# counter:  12 -------  loss :  tf.Tensor(38605.45, shape=(), dtype=float32)
# ***** Episode  1959  *****
# counter:  1 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1960  *****
# counter:  19 -------  loss :  tf.Tensor(2292.2183, shape=(), dtype=float32)
# ***** Episode  1961  *****
# counter:  55 -------  loss :  tf.Tensor(9564.716, shape=(), dtype=float32)
# ***** Episode  1962  *****
# counter:  25 -------  loss :  tf.Tensor(1132.241, shape=(), dtype=float32)
# ***** Episode  1963  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1964  *****
# counter:  25 -------  loss :  tf.Tensor(25343.004, shape=(), dtype=float32)
# ***** Episode  1965  *****
# counter:  7 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1966  *****
# counter:  24 -------  loss :  tf.Tensor(1986.7491, shape=(), dtype=float32)
# ***** Episode  1967  *****
# counter:  10 -------  loss :  tf.Tensor(3421.2488, shape=(), dtype=float32)
# ***** Episode  1968  *****
# counter:  16 -------  loss :  tf.Tensor(51433.805, shape=(), dtype=float32)
# ***** Episode  1969  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1970  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1971  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1972  *****
# counter:  10 -------  loss :  tf.Tensor(62085.727, shape=(), dtype=float32)
# ***** Episode  1973  *****
# counter:  6 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1974  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1975  *****
# counter:  10 -------  loss :  tf.Tensor(3439.5496, shape=(), dtype=float32)
# ***** Episode  1976  *****
# counter:  65 -------  loss :  tf.Tensor(16651.67, shape=(), dtype=float32)
# ***** Episode  1977  *****
# counter:  15 -------  loss :  tf.Tensor(1920.0273, shape=(), dtype=float32)
# ***** Episode  1978  *****
# counter:  39 -------  loss :  tf.Tensor(38280.16, shape=(), dtype=float32)
# ***** Episode  1979  *****
# counter:  27 -------  loss :  tf.Tensor(25429.207, shape=(), dtype=float32)
# ***** Episode  1980  *****
# counter:  22 -------  loss :  tf.Tensor(22632.781, shape=(), dtype=float32)
# ***** Episode  1981  *****
# counter:  8 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1982  *****
# counter:  22 -------  loss :  tf.Tensor(1097.1296, shape=(), dtype=float32)
# ***** Episode  1983  *****
# counter:  41 -------  loss :  tf.Tensor(1138.2323, shape=(), dtype=float32)
# ***** Episode  1984  *****
# counter:  12 -------  loss :  tf.Tensor(45296.7, shape=(), dtype=float32)
# ***** Episode  1985  *****
# counter:  13 -------  loss :  tf.Tensor(46105.902, shape=(), dtype=float32)
# ***** Episode  1986  *****
# counter:  11 -------  loss :  tf.Tensor(2082.0583, shape=(), dtype=float32)
# ***** Episode  1987  *****
# counter:  4 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1988  *****
# counter:  10 -------  loss :  tf.Tensor(2432.9316, shape=(), dtype=float32)
# ***** Episode  1989  *****
# counter:  10 -------  loss :  tf.Tensor(53079.07, shape=(), dtype=float32)
# ***** Episode  1990  *****
# counter:  14 -------  loss :  tf.Tensor(772.6409, shape=(), dtype=float32)
# ***** Episode  1991  *****
# counter:  18 -------  loss :  tf.Tensor(297.33197, shape=(), dtype=float32)
# ***** Episode  1992  *****
# counter:  30 -------  loss :  tf.Tensor(17591.639, shape=(), dtype=float32)
# ***** Episode  1993  *****
# counter:  23 -------  loss :  tf.Tensor(72966.33, shape=(), dtype=float32)
# ***** Episode  1994  *****
# counter:  10 -------  loss :  tf.Tensor(53866.363, shape=(), dtype=float32)
# ***** Episode  1995  *****
# counter:  9 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1996  *****
# counter:  12 -------  loss :  tf.Tensor(50234.324, shape=(), dtype=float32)
# ***** Episode  1997  *****
# counter:  30 -------  loss :  tf.Tensor(14091.312, shape=(), dtype=float32)
# ***** Episode  1998  *****
# counter:  2 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)
# ***** Episode  1999  *****
# alpha:  1.0 delta:  1.5
# alpha:  1.5 delta:  1.5
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# alpha:  0.5 delta:  1.25
# counter:  200 -------  loss :  tf.Tensor(nan, shape=(), dtype=float32)

# %%
x, y = np.transpose(states_final_policy)[0], np.transpose(states_final_policy)[1]
plt.figure()
plt.grid()
plt.title("Policy learned")
plt.plot(range(len(x)), x, '-b', label = 'Rabbits')
plt.plot(range(len(y)), y, '-r', label = "Lynxes")
plt.xlabel('Time t, [days]')
plt.ylabel('Population')
plt.legend()

plt.show()

# %%
env.plotter.plot()

# %%
#from google.colab import drive
#drive.mount('/content/drive/')

# %%
#q_network.save('../content/drive/Othercomputers/Il mio laptop/final-project/Models/network_alpha_delta_variabili')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: ../content/drive/Othercomputers/Il mio laptop/final-project/Models/network_alpha_delta_variabili/assets

# %% [markdown]
# ALPHA E DELTA con 5
#
# inputs = layers.Input(shape=(N_STATE,))  # input dimension  \\
# idden1 = layers.Dense(32, activation="relu", kernel_initializer=initializers.he_normal())(inputs)   \\
# hidden2 = layers.Dense(32, activation="relu", kernel_initializer=initializers.he_normal())(hidden1)   \\
# q_values = layers.Dense(N_ACTIONS, activation="linear")(hidden2)
#
# sim_input = sim_init(num_episodes=2000, discount=0.9, lr=0.00001, epsilon=0.1)
